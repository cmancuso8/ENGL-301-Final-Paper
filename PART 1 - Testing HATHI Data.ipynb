# %%
# This was my first attempt at gathering data, which I sourced from https://github.com/tedunderwood/noveltmmeta
    # This is detailed in Prof. Ted Underwood's interesting paper "NovelTM Datasets for English-Language Fiction, 1700-2009", found here: 
        # https://culturalanalytics.org/article/13147-noveltm-datasets-for-english-language-fiction-1700-2009
        
    # Unfortunately, the data only contains the metadata of the massive HathiTrust corpus it represents(138 000 novels!), it's interesting, but useless for advanced computer modelling
        # I attempted to download it to then link it to the full novels it listed, this proved to likely be impossible without a research connection to the HathiTrust

# %%
import pandas as pd
import codecs
import numpy as np
import glob
import os
import csv

# %%
# Here, I'm creating a path to the data files, and importing them into a dataframe

filepath = 'C:\\Users\\kayde\\Desktop\\ENGL 301\\titlemeta.tsv.txt'
file_df = pd.read_csv(filepath, sep='\t', quoting=csv.QUOTE_NONE, encoding='latin1', error_bad_lines=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 63303: expected 30 fields, saw 37\n'
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4,5,7,16,18,19,21,23,26) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# This is me removing data without dates, and filtering those out
file_df_0 = file_df.copy()
file_df_0['inferreddate'] = file_df_0['inferreddate'].fillna(0)

nan_df = file_df_0.loc[file_df_0['inferreddate'] == 0]
nan_df
# Out:
#                   docid                    oldauthor  \
# 0    mdp.39015031913893         Spencer, Louise Reid
# 1    mdp.39015003936864              Baker, Robert H
# 2    mdp.39015068342305             Dickens, Charles
# 3    mdp.39015055066586              Stretton, Hesba
# 4    mdp.39015055066594               Stretton,Hesba
# ..                  ...                          ...
# 582  uc1.32106019617783  Ainsworth, William Harrison
# 583  uc1.32106019617791  Ainsworth, William Harrison
# 584  mdp.39015031231197             Deeping, Warwick
# 585  mdp.39015010423583                 Franko, Ivan
# 586      wu.89101299501                          NaN
#
#                           author  authordate inferreddate latestcomp datetype  \
# 0           Spencer, Louise Reid         NaN            0        NaN        |
# 1                Baker, Robert H         NaN            0        NaN        n
# 2               Dickens, Charles  1812-1870.            0     1870.0        n
# ...

# %%
# This is simply a printout of everything included in the metadata, interesting, but sadly not helpful to me
for col in file_df.columns:
    print(col)
# Out:
# docid
# oldauthor
# author
# authordate
# inferreddate
# latestcomp
# datetype
# startdate
# enddate
# imprint
# imprintdate
# contents
# genres
# subjects
# geographics
# locnum
# oclc
# place
# recordid
# instances
# allcopiesofwork
# copiesin25yrs
# enumcron
# volnum
# title
# parttitle
# earlyedition
# shorttitle
# nonficprob
# juvenileprob

# %%
file_df.loc[:,"recordid"]
# With this, I hoped to be able to create a program to use this list of id numbers to find that novel in the HathiTrust libary, download it, and link it to the book's metadata
    # Unfortunately, this proved not to be possible on a mass scale with the current structure of HathiTrust and my student privledges
# Out:
# 0              8744
# 1             39757
# 2            119996
# 3            122460
# 4            122464
#             ...
# 138158    100673332
# 138159      9933504
# 138160     11803426
# 138161     12240457
# 138162    100173184
# Name: recordid, Length: 138163, dtype: object

# %%
file_df_0 = file_df.copy()
file_df_0['oclc'] = file_df_0['oclc'].fillna(0)

nan_df = file_df_0.loc[file_df_0['oclc'] == 0]
nan_df
# Out:
#                      docid                           oldauthor  \
# 62      mdp.39015080467205                   Malatesta, Errico
# 65      mdp.39015080478541                                 NaN
# 78      mdp.39015064964151                     Martinez, Pedro
# 79      mdp.39015070750792  Reeve, Arthur B. (Arthur Benjamin)
# 87      inu.39000001222475                                 NaN
# ...                    ...                                 ...
# 136827  mdp.39015077624222                     Brooks, Charlie
# 136988  mdp.39015082680227                      Sandford, John
# 137265  mdp.39015079339571                DaRoy, Ester Vallado
# 137938  mdp.39015079311984                        Casey, Kevin
# 137941  mdp.39015079312438                     Downey, Garbhan
#
#                                     author     authordate inferreddate  \
# 62                       Malatesta, Errico     1853-1932.          NaN
# ...
